# %% [markdown]
# # Check GPU

# %%
import torch
print(torch.cuda.device_count()) 
print(torch.cuda.is_available())
print(torch.__version__)
print(torch.cuda.current_device())
# Out:
# 1
# True
# 1.13.1
# 0

# %% [markdown]
# # Fine-tune Whisper

# %% [markdown]
# ## Prepare Data and Model

# %% [markdown]
# ### Load Model

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")

# %% [markdown]
# ### Load Datasets

# %%
AUDIO_COLUMN_NAME = "audio"
TEXT_COLUMN_NAME = "sentence"

# %%
from datasets import Audio

def normalize_dataset(ds, audio_column_name=None, text_column_name=None):

    if audio_column_name is not None and audio_column_name != AUDIO_COLUMN_NAME:
        ds = ds.rename_column(audio_column_name, AUDIO_COLUMN_NAME)

    if text_column_name is not None and text_column_name != TEXT_COLUMN_NAME:
        ds = ds.rename_column(text_column_name, TEXT_COLUMN_NAME)

    # resample to the same sampling rate
    ds = ds.cast_column("audio", Audio(sampling_rate=16_000))

    # normalise columns to ["audio", "sentence"]
    ds = ds.remove_columns(set(ds.features.keys()) - set([AUDIO_COLUMN_NAME, TEXT_COLUMN_NAME]))
    
    return ds

# %% [markdown]
# ### Use huggingface API

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset, DatasetDict

datasets = DatasetDict()

# %%
dataset = load_dataset("mozilla-foundation/common_voice_11_0", "fr", split="test", use_auth_token=True)
dataset = normalize_dataset(dataset)
# Out:
# Downloading and preparing dataset common_voice_11_0/fr to /home/user/.cache/huggingface/datasets/mozilla-foundation___common_voice_11_0/fr/11.0.0/2c65b95d99ca879b1b1074ea197b65e0497848fd697fdb0582e0f6b75b6f4da0...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.53G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.48G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.49G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.44G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.80G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/702M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.80G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/652M [00:00<?, ?B/s]
# Computing checksums of downloaded files. They can be used for integrity verification. You can disable this by passing ignore_verifications=True to load_dataset
# Computing checksums:  11%|#1        | 2/18 [00:09<01:15,  4.74s/it]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/125M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.83M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.81M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.68M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.4M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 485034it [00:02, 205255.42it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 16089it [00:00, 232818.32it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 16089it [00:00, 213370.17it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 14359it [00:00, 224294.58it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 57607it [00:00, 228340.74it/s]
# Dataset common_voice_11_0 downloaded and prepared to /home/user/.cache/huggingface/datasets/mozilla-foundation___common_voice_11_0/fr/11.0.0/2c65b95d99ca879b1b1074ea197b65e0497848fd697fdb0582e0f6b75b6f4da0. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# Dataset({
#     features: ['audio', 'sentence'],
#     num_rows: 16089
# })

# %% [markdown]
# ### Split dataset into train and test

# %%
num_train_examples = 200
num_test_examples = 50

datasets["train"] = dataset.select(range(num_train_examples))
datasets["eval"] =  dataset.select(range(num_test_examples))

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 200
#     })
#     eval: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 50
#     })
# })

# %% [markdown]
# # Data Augmentation

# %%
# !pip install audiomentations
# Out:
# Collecting audiomentations
#   Downloading audiomentations-0.30.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from audiomentations) (1.23.5)
# Requirement already satisfied: scipy<2,>=1.0.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from audiomentations) (1.10.1)
# Collecting librosa<0.10.0,>0.7.2
#   Using cached librosa-0.9.2-py3-none-any.whl (214 kB)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (23.1)
# Requirement already satisfied: decorator>=4.0.10 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.6.0)
# Requirement already satisfied: numba>=0.45.1 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.56.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.2.1)
# Requirement already satisfied: joblib>=0.14 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.2.0)
# Requirement already satisfied: soundfile>=0.10.2 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from librosa<0.10.0,>0.7.2->audiomentations) (3.0.0)
# Collecting resampy>=0.2.2
#   Using cached resampy-0.4.2-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: setuptools in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from numba>=0.45.1->librosa<0.10.0,>0.7.2->audiomentations) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from numba>=0.45.1->librosa<0.10.0,>0.7.2->audiomentations) (0.39.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa<0.10.0,>0.7.2->audiomentations) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (1.15.1)
# Requirement already satisfied: pycparser in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.26.14)
# Installing collected packages: resampy, librosa, audiomentations
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.0
#     Uninstalling librosa-0.10.0:
#       Successfully uninstalled librosa-0.10.0
# Successfully installed audiomentations-0.30.0 librosa-0.9.2 resampy-0.4.2

# %%
from audiomentations import (
    AddBackgroundNoise,
    AddGaussianNoise,
    Compose,
    Gain,
    OneOf,
    PitchShift,
    PolarityInversion,
    TimeStretch,
)

# %% [markdown]
# ### define augmentation

# %%
augmentation = Compose(
    [
        TimeStretch(min_rate=0.9, max_rate=1.1, p=0.2, leave_length_unchanged=False),
    ]
)

# %%
def augment_dataset(batch):
    # load and (possibly) resample audio data to 16kHz
    sample = batch[AUDIO_COLUMN_NAME]

    # apply augmentation
    augmented_waveform = augmentation(sample["array"], sample_rate=sample["sampling_rate"])
    batch[AUDIO_COLUMN_NAME]["array"] = augmented_waveform
    return batch

# %% [markdown]
# ### augment training data

# %%
preprocessing_num_workers = 1

augmented_raw_training_dataset = datasets["train"].map(
    augment_dataset, num_proc=preprocessing_num_workers, desc="augment train dataset"
)
# Out:
# augment train dataset:   0%|          | 0/200 [00:00<?, ?ex/s]

# %% [markdown]
# ### Combine raw data and augment data

# %%
from datasets import concatenate_datasets

datasets["train"] = concatenate_datasets([datasets["train"], augmented_raw_training_dataset])
datasets["train"] = datasets["train"].shuffle(seed=10)

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 400
#     })
#     eval: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 50
#     })
# })

# %% [markdown]
# ## Preprocessing

# %%
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

normalizer = BasicTextNormalizer()

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="french", task="transcribe")

# %%
do_normalize_text = True


def prepare_dataset(batch):

    # load
    audio = batch[AUDIO_COLUMN_NAME]

    # compute log-Mel input features from input audio array
    batch["input_features"] = processor.feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # compute input length of audio sample in seconds
    batch["input_length"] = len(audio["array"]) / audio["sampling_rate"]

    # process targets
    input_str = normalizer(batch[TEXT_COLUMN_NAME]).strip() if do_normalize_text else batch[TEXT_COLUMN_NAME]
    
    # encode target text to label ids
    batch["labels"] = processor.tokenizer(input_str).input_ids

    return batch

# %%
vectorized_datasets = datasets.map(
    prepare_dataset, remove_columns=next(iter(datasets.values())).column_names, desc="preprocess dataset"
)
# Out:
# preprocess dataset:   0%|          | 0/400 [00:00<?, ?ex/s]
# preprocess dataset:   0%|          | 0/50 [00:00<?, ?ex/s]

# %% [markdown]
# ## Training and Evaluation

# %% [markdown]
# ### Data Collator

# %%
from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [{"input_features": feature["input_features"]} for feature in features]

        # convert to tensors
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        
        # pad label ids to the max length in the batch
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %% [markdown]
# ### Evaluation Metrics

# %%
import evaluate

metric = evaluate.load("wer")

# %%
# evaluate with the 'normalised' WER
do_normalize_eval = True


def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    if do_normalize_eval:
        pred_str = [normalizer(pred) for pred in pred_str]

        # perhaps already normalised
        label_str = [normalizer(label) for label in label_str]
        
        # filtering step to only evaluate the samples that correspond to non-zero references
        pred_str = [pred_str[i] for i in range(len(pred_str)) if len(label_str[i]) > 0]
        label_str = [label_str[i] for i in range(len(label_str)) if len(label_str[i]) > 0]

    wer = metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer}

# %% [markdown]
# ### Training Configuration

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./outputs/whisper_medium_ft",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=1,
    warmup_steps=800,
    max_steps=8000,
    learning_rate=6.25e-6,
    weight_decay=0.01,
    gradient_checkpointing=True,
    fp16=True,
    predict_with_generate=True,
    generation_max_length=225,
    logging_steps=25,
    report_to=["tensorboard"],
    evaluation_strategy="steps",
    eval_steps=1000,
    save_strategy="steps",
    save_steps=1000,
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
)
# Out:
# PyTorch: setting up devices

# %% [markdown]
# ### Initialize Trainer

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=vectorized_datasets["train"],
    eval_dataset=vectorized_datasets["eval"],
    tokenizer=processor,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs
# Using cuda_amp half precision backend

# %% [markdown]
# ### GPU check again

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

print(f"Using GPU is CUDA:{os.environ['CUDA_VISIBLE_DEVICES']}")

for i in range(torch.cuda.device_count()):
    info = torch.cuda.get_device_properties(i)
    print(f"CUDA:{i} {info.name}, {info.total_memory / 1024 ** 2}MB")

device = torch.device("cuda:0")
# Out:
# Using GPU is CUDA:1
# CUDA:0 NVIDIA GeForce RTX 4090, 24195.125MB

# %% [markdown]
# ### Training

# %%
train_result = trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `WhisperForConditionalGeneration.forward` and have been ignored: input_length. If input_length are not expected by `WhisperForConditionalGeneration.forward`,  you can safely ignore this message.
# /home/user/miniconda3/envs/asr_new/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 400
#   Num Epochs = 320
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8000
#   Number of trainable parameters = 241734912
#   0%|          | 0/8000 [00:00<?, ?it/s]
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 53.1181, 'learning_rate': 1.875e-07, 'epoch': 1.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 52.388, 'learning_rate': 3.828125e-07, 'epoch': 2.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 50.7311, 'learning_rate': 5.78125e-07, 'epoch': 3.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 48.0142, 'learning_rate': 7.734375000000001e-07, 'epoch': 4.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 45.4373, 'learning_rate': 9.375e-07, 'epoch': 5.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 44.5122, 'learning_rate': 1.1328125e-06, 'epoch': 6.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 43.2381, 'learning_rate': 1.328125e-06, 'epoch': 7.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 41.1915, 'learning_rate': 1.5234375e-06, 'epoch': 8.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 37.2746, 'learning_rate': 1.7187500000000003e-06, 'epoch': 9.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 28.0446, 'learning_rate': 1.8984375000000002e-06, 'epoch': 10.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 13.4677, 'learning_rate': 2.09375e-06, 'epoch': 11.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 9.1882, 'learning_rate': 2.2890625e-06, 'epoch': 12.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 7.6227, 'learning_rate': 2.4843750000000002e-06, 'epoch': 13.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 6.6516, 'learning_rate': 2.6796875000000003e-06, 'epoch': 14.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 6.2109, 'learning_rate': 2.8750000000000004e-06, 'epoch': 15.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 5.9154, 'learning_rate': 3.0703125e-06, 'epoch': 16.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 5.8094, 'learning_rate': 3.2656249999999998e-06, 'epoch': 17.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 5.617, 'learning_rate': 3.4609375e-06, 'epoch': 18.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 5.5272, 'learning_rate': 3.65625e-06, 'epoch': 19.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# ...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 0.0126, 'learning_rate': 1.1458333333333334e-07, 'epoch': 315.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 0.0123, 'learning_rate': 9.288194444444445e-08, 'epoch': 316.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 0.0121, 'learning_rate': 7.118055555555556e-08, 'epoch': 317.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 0.012, 'learning_rate': 4.9479166666666674e-08, 'epoch': 318.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 0.0118, 'learning_rate': 2.777777777777778e-08, 'epoch': 319.0}
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# The following columns in the evaluation set don't have a corresponding argument in `WhisperForConditionalGeneration.forward` and have been ignored: input_length. If input_length are not expected by `WhisperForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# {'loss': 0.0117, 'learning_rate': 6.076388888888889e-09, 'epoch': 320.0}
#   0%|          | 0/7 [00:00<?, ?it/s]
# Saving model checkpoint to ./outputs/whisper_medium_ft/checkpoint-8000
# Configuration saved in ./outputs/whisper_medium_ft/checkpoint-8000/config.json
# Configuration saved in ./outputs/whisper_medium_ft/checkpoint-8000/generation_config.json
# {'eval_loss': 0.008823619224131107, 'eval_wer': 14.549425287356321, 'eval_runtime': 20.6724, 'eval_samples_per_second': 2.419, 'eval_steps_per_second': 0.339, 'epoch': 320.0}
# Model weights saved in ./outputs/whisper_medium_ft/checkpoint-8000/pytorch_model.bin
# Feature extractor saved in ./outputs/whisper_medium_ft/checkpoint-8000/preprocessor_config.json
# tokenizer config file saved in ./outputs/whisper_medium_ft/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./outputs/whisper_medium_ft/checkpoint-8000/special_tokens_map.json
# added tokens file saved in ./outputs/whisper_medium_ft/checkpoint-8000/added_tokens.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./outputs/whisper_medium_ft/checkpoint-8000 (score: 14.549425287356321).
# {'train_runtime': 16560.319, 'train_samples_per_second': 7.729, 'train_steps_per_second': 0.483, 'train_loss': 2.560914797578007, 'epoch': 320.0}

# %%
model.save_pretrained(training_args.output_dir)
processor.save_pretrained(training_args.output_dir)
# Out:
# Configuration saved in ./outputs/whisper_medium_ft/config.json
# Configuration saved in ./outputs/whisper_medium_ft/generation_config.json
# Model weights saved in ./outputs/whisper_medium_ft/pytorch_model.bin
# Feature extractor saved in ./outputs/whisper_medium_ft/preprocessor_config.json
# tokenizer config file saved in ./outputs/whisper_medium_ft/tokenizer_config.json
# Special tokens file saved in ./outputs/whisper_medium_ft/special_tokens_map.json
# added tokens file saved in ./outputs/whisper_medium_ft/added_tokens.json

# %% [markdown]
# ## Evaluation

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small",  language="french", task="transcribe")
# Out:
# loading file vocab.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/vocab.json
# loading file tokenizer.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/tokenizer.json
# loading file merges.txt from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/merges.txt
# loading file normalizer.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/normalizer.json
# loading file added_tokens.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/added_tokens.json
# loading file special_tokens_map.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/special_tokens_map.json
# loading file tokenizer_config.json from cache at /home/user/.cache/huggingface/hub/models--openai--whisper-small/snapshots/f6744499d1eba717bcf4d6be735e3d386ffb60ad/tokenizer_config.json
# Adding <|startoftranscript|> to the vocabulary
# Adding <|en|> to the vocabulary
# Adding <|zh|> to the vocabulary
# Adding <|de|> to the vocabulary
# Adding <|es|> to the vocabulary
# Adding <|ru|> to the vocabulary
# Adding <|ko|> to the vocabulary
# Adding <|fr|> to the vocabulary
# Adding <|ja|> to the vocabulary
# Adding <|pt|> to the vocabulary
# Adding <|tr|> to the vocabulary
# Adding <|pl|> to the vocabulary
# Adding <|ca|> to the vocabulary
# Adding <|nl|> to the vocabulary
# Adding <|ar|> to the vocabulary
# Adding <|sv|> to the vocabulary
# Adding <|it|> to the vocabulary
# Adding <|id|> to the vocabulary
# Adding <|hi|> to the vocabulary
# Adding <|fi|> to the vocabulary
# Adding <|vi|> to the vocabulary
# Adding <|he|> to the vocabulary
# Adding <|uk|> to the vocabulary
# Adding <|el|> to the vocabulary
# Adding <|ms|> to the vocabulary
# Adding <|cs|> to the vocabulary
# Adding <|ro|> to the vocabulary
# Adding <|da|> to the vocabulary
# Adding <|hu|> to the vocabulary
# Adding <|ta|> to the vocabulary
# Adding <|no|> to the vocabulary
# Adding <|th|> to the vocabulary
# Adding <|ur|> to the vocabulary
# Adding <|hr|> to the vocabulary
# Adding <|bg|> to the vocabulary
# Adding <|lt|> to the vocabulary
# Adding <|la|> to the vocabulary
# Adding <|mi|> to the vocabulary
# Adding <|ml|> to the vocabulary
# Adding <|cy|> to the vocabulary
# Adding <|sk|> to the vocabulary
# Adding <|te|> to the vocabulary
# Adding <|fa|> to the vocabulary
# Adding <|lv|> to the vocabulary
# Adding <|bn|> to the vocabulary
# Adding <|sr|> to the vocabulary
# Adding <|az|> to the vocabulary
# Adding <|sl|> to the vocabulary
# Adding <|kn|> to the vocabulary
# Adding <|et|> to the vocabulary
# Adding <|mk|> to the vocabulary
# Adding <|br|> to the vocabulary
# Adding <|eu|> to the vocabulary
# Adding <|is|> to the vocabulary
# Adding <|hy|> to the vocabulary
# Adding <|ne|> to the vocabulary
# Adding <|mn|> to the vocabulary
# Adding <|bs|> to the vocabulary
# Adding <|kk|> to the vocabulary
# Adding <|sq|> to the vocabulary
# Adding <|sw|> to the vocabulary
# Adding <|gl|> to the vocabulary
# Adding <|mr|> to the vocabulary
# Adding <|pa|> to the vocabulary
# Adding <|si|> to the vocabulary
# Adding <|km|> to the vocabulary
# Adding <|sn|> to the vocabulary
# Adding <|yo|> to the vocabulary
# Adding <|so|> to the vocabulary
# Adding <|af|> to the vocabulary
# Adding <|oc|> to the vocabulary
# Adding <|ka|> to the vocabulary
# Adding <|be|> to the vocabulary
# Adding <|tg|> to the vocabulary
# Adding <|sd|> to the vocabulary
# Adding <|gu|> to the vocabulary
# Adding <|am|> to the vocabulary
# Adding <|yi|> to the vocabulary
# Adding <|lo|> to the vocabulary
# Adding <|uz|> to the vocabulary
# Adding <|fo|> to the vocabulary
# Adding <|ht|> to the vocabulary
# Adding <|ps|> to the vocabulary
# Adding <|tk|> to the vocabulary
# Adding <|nn|> to the vocabulary
# Adding <|mt|> to the vocabulary
# Adding <|sa|> to the vocabulary
# Adding <|lb|> to the vocabulary
# Adding <|my|> to the vocabulary
# Adding <|bo|> to the vocabulary
# Adding <|tl|> to the vocabulary
# Adding <|mg|> to the vocabulary
# Adding <|as|> to the vocabulary
# Adding <|tt|> to the vocabulary
# Adding <|haw|> to the vocabulary
# Adding <|ln|> to the vocabulary
# Adding <|ha|> to the vocabulary
# Adding <|ba|> to the vocabulary
# Adding <|jw|> to the vocabulary
# Adding <|su|> to the vocabulary
# Adding <|translate|> to the vocabulary
# Adding <|transcribe|> to the vocabulary
# Adding <|startoflm|> to the vocabulary
# Adding <|startofprev|> to the vocabulary
# Adding <|nocaptions|> to the vocabulary
# Adding <|notimestamps|> to the vocabulary

# %%
eval_metrics = trainer.evaluate(metric_key_prefix="eval")

eval_metrics
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `WhisperForConditionalGeneration.forward` and have been ignored: input_length. If input_length are not expected by `WhisperForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
#   0%|          | 0/7 [00:00<?, ?it/s]
# {'eval_loss': 0.008823619224131107,
#  'eval_wer': 14.549425287356321,
#  'eval_runtime': 20.5723,
#  'eval_samples_per_second': 2.43,
#  'eval_steps_per_second': 0.34,
#  'epoch': 320.0}

# %%
trainer.state.log_history
# Out:
# [{'loss': 53.1181, 'learning_rate': 1.875e-07, 'epoch': 1.0, 'step': 25},
#  {'loss': 52.388, 'learning_rate': 3.828125e-07, 'epoch': 2.0, 'step': 50},
#  {'loss': 50.7311, 'learning_rate': 5.78125e-07, 'epoch': 3.0, 'step': 75},
#  {'loss': 48.0142,
#   'learning_rate': 7.734375000000001e-07,
#   'epoch': 4.0,
#   'step': 100},
#  {'loss': 45.4373, 'learning_rate': 9.375e-07, 'epoch': 5.0, 'step': 125},
#  {'loss': 44.5122, 'learning_rate': 1.1328125e-06, 'epoch': 6.0, 'step': 150},
#  {'loss': 43.2381, 'learning_rate': 1.328125e-06, 'epoch': 7.0, 'step': 175},
#  {'loss': 41.1915, 'learning_rate': 1.5234375e-06, 'epoch': 8.0, 'step': 200},
#  {'loss': 37.2746,
#   'learning_rate': 1.7187500000000003e-06,
#   'epoch': 9.0,
#   'step': 225},
#  {'loss': 28.0446,
#   'learning_rate': 1.8984375000000002e-06,
#   'epoch': 10.0,
#   'step': 250},
#  {'loss': 13.4677, 'learning_rate': 2.09375e-06, 'epoch': 11.0, 'step': 275},
#  {'loss': 9.1882, 'learning_rate': 2.2890625e-06, 'epoch': 12.0, 'step': 300},
#  {'loss': 7.6227,
#   'learning_rate': 2.4843750000000002e-06,
#   'epoch': 13.0,
#   'step': 325},
#  {'loss': 6.6516,
#   'learning_rate': 2.6796875000000003e-06,
#   'epoch': 14.0,
#   'step': 350},
#  {'loss': 6.2109,
#   'learning_rate': 2.8750000000000004e-06,
#   'epoch': 15.0,
#   'step': 375},
#  {'loss': 5.9154, 'learning_rate': 3.0703125e-06, 'epoch': 16.0, 'step': 400},
#  {'loss': 5.8094,
#   'learning_rate': 3.2656249999999998e-06,
#   'epoch': 17.0,
#   'step': 425},
#  {'loss': 5.617, 'learning_rate': 3.4609375e-06, 'epoch': 18.0, 'step': 450},
#  {'loss': 5.5272, 'learning_rate': 3.65625e-06, 'epoch': 19.0, 'step': 475},
#  {'loss': 5.4359, 'learning_rate': 3.8515625e-06, 'epoch': 20.0, 'step': 500},
#  {'loss': 5.3691, 'learning_rate': 4.046875e-06, 'epoch': 21.0, 'step': 525},
#  {'loss': 5.2662, 'learning_rate': 4.2421875e-06, 'epoch': 22.0, 'step': 550},
#  {'loss': 5.2088, 'learning_rate': 4.4375e-06, 'epoch': 23.0, 'step': 575},
#  {'loss': 5.2305, 'learning_rate': 4.6328125e-06, 'epoch': 24.0, 'step': 600},
#  {'loss': 5.1094, 'learning_rate': 4.828125e-06, 'epoch': 25.0, 'step': 625},
#  {'loss': 5.0345, 'learning_rate': 5.0234375e-06, 'epoch': 26.0, 'step': 650},
#  {'loss': 4.9789, 'learning_rate': 5.21875e-06, 'epoch': 27.0, 'step': 675},
#  {'loss': 4.9643, 'learning_rate': 5.4140625e-06, 'epoch': 28.0, 'step': 700},
#  {'loss': 4.8868, 'learning_rate': 5.609375e-06, 'epoch': 29.0, 'step': 725},
#  {'loss': 4.8571, 'learning_rate': 5.8046875e-06, 'epoch': 30.0, 'step': 750},
#  {'loss': 4.806, 'learning_rate': 6e-06, 'epoch': 31.0, 'step': 775},
#  {'loss': 5.0046, 'learning_rate': 6.1953125e-06, 'epoch': 32.0, 'step': 800},
#  {'loss': 4.8969,
#   'learning_rate': 6.234375000000001e-06,
#   'epoch': 33.0,
#   'step': 825},
#  {'loss': 4.7612,
#   'learning_rate': 6.212673611111111e-06,
#   'epoch': 34.0,
#   'step': 850},
#  {'loss': 4.7528,
#   'learning_rate': 6.190972222222222e-06,
#   'epoch': 35.0,
#   'step': 875},
#  {'loss': 4.7164,
#   'learning_rate': 6.169270833333334e-06,
#   'epoch': 36.0,
#   'step': 900},
#  {'loss': 4.6469,
#   'learning_rate': 6.147569444444445e-06,
#   'epoch': 37.0,
#   'step': 925},
#  {'loss': 4.5885,
#   'learning_rate': 6.125868055555556e-06,
#   'epoch': 38.0,
#   'step': 950},
#  {'loss': 4.5533,
#   'learning_rate': 6.104166666666667e-06,
#   'epoch': 39.0,
#   'step': 975},
#  {'loss': 4.5118,
#   'learning_rate': 6.082465277777779e-06,
#   'epoch': 40.0,
#   'step': 1000},
#  {'eval_loss': 4.2763495445251465,
#   'eval_wer': 19.908045977011493,
#   'eval_runtime': 20.6376,
#   'eval_samples_per_second': 2.423,
#   'eval_steps_per_second': 0.339,
#   'epoch': 40.0,
#   'step': 1000},
#  {'loss': 4.4573,
#   'learning_rate': 6.060763888888889e-06,
#   'epoch': 41.0,
#   'step': 1025},
#  {'loss': 4.4229, 'learning_rate': 6.0390625e-06, 'epoch': 42.0, 'step': 1050},
#  {'loss': 4.373,
#   'learning_rate': 6.0173611111111115e-06,
#   'epoch': 43.0,
#   'step': 1075},
#  {'loss': 4.351,
#   'learning_rate': 5.995659722222222e-06,
#   'epoch': 44.0,
#   'step': 1100},
#  {'loss': 4.2889,
#   'learning_rate': 5.973958333333333e-06,
#   'epoch': 45.0,
#   'step': 1125},
#  {'loss': 4.2504,
#   'learning_rate': 5.952256944444444e-06,
#   'epoch': 46.0,
#   'step': 1150},
#  {'loss': 4.2124,
#   'learning_rate': 5.930555555555556e-06,
#   'epoch': 47.0,
#   'step': 1175},
#  {'loss': 4.1705,
#   'learning_rate': 5.908854166666667e-06,
#   'epoch': 48.0,
#   'step': 1200},
#  {'loss': 4.1324,
#   'learning_rate': 5.887152777777778e-06,
#   'epoch': 49.0,
#   'step': 1225},
#  {'loss': 4.0604,
#   'learning_rate': 5.865451388888889e-06,
#   'epoch': 50.0,
#   'step': 1250},
#  {'loss': 4.041,
#   'learning_rate': 5.843750000000001e-06,
#   'epoch': 51.0,
#   'step': 1275},
#  {'loss': 4.1356,
#   'learning_rate': 5.822048611111111e-06,
#   'epoch': 52.0,
#   'step': 1300},
#  {'loss': 4.0097,
#   'learning_rate': 5.800347222222222e-06,
#   'epoch': 53.0,
#   'step': 1325},
#  {'loss': 3.9009,
#   'learning_rate': 5.7786458333333335e-06,
#   'epoch': 54.0,
#   'step': 1350},
#  {'loss': 3.8424,
#   'learning_rate': 5.756944444444445e-06,
#   'epoch': 55.0,
#   'step': 1375},
#  {'loss': 3.7993,
#   'learning_rate': 5.735243055555556e-06,
#   'epoch': 56.0,
#   'step': 1400},
#  {'loss': 3.7159,
#   'learning_rate': 5.713541666666667e-06,
#   'epoch': 57.0,
#   'step': 1425},
#  {'loss': 3.6506,
#   'learning_rate': 5.6918402777777784e-06,
#   'epoch': 58.0,
#   'step': 1450},
#  {'loss': 3.5727,
#   'learning_rate': 5.67013888888889e-06,
#   'epoch': 59.0,
#   'step': 1475},
#  {'loss': 3.5067,
#   'learning_rate': 5.648437500000001e-06,
#   'epoch': 60.0,
#   'step': 1500},
#  {'loss': 3.4981,
#   'learning_rate': 5.626736111111111e-06,
#   'epoch': 61.0,
#   'step': 1525},
#  {'loss': 3.427,
#   'learning_rate': 5.6050347222222226e-06,
#   'epoch': 62.0,
#   'step': 1550},
#  {'loss': 3.3834,
#   'learning_rate': 5.583333333333334e-06,
#   'epoch': 63.0,
#   'step': 1575},
#  {'loss': 3.3446,
#   'learning_rate': 5.561631944444445e-06,
#   'epoch': 64.0,
#   'step': 1600},
#  {'loss': 3.3063,
#   'learning_rate': 5.5399305555555554e-06,
#   'epoch': 65.0,
#   'step': 1625},
#  {'loss': 3.1996,
#   'learning_rate': 5.518229166666667e-06,
#   'epoch': 66.0,
#   'step': 1650},
#  {'loss': 3.138,
#   'learning_rate': 5.496527777777778e-06,
#   'epoch': 67.0,
#   'step': 1675},
#  {'loss': 3.117,
#   'learning_rate': 5.474826388888889e-06,
#   'epoch': 68.0,
#   'step': 1700},
#  {'loss': 3.0822, 'learning_rate': 5.453125e-06, 'epoch': 69.0, 'step': 1725},
#  {'loss': 3.0408,
#   'learning_rate': 5.431423611111111e-06,
#   'epoch': 70.0,
#   'step': 1750},
#  {'loss': 2.9332,
#   'learning_rate': 5.409722222222222e-06,
#   'epoch': 71.0,
#   'step': 1775},
#  {'loss': 2.9627,
#   'learning_rate': 5.388020833333333e-06,
#   'epoch': 72.0,
#   'step': 1800},
#  {'loss': 2.8925,
#   'learning_rate': 5.3663194444444445e-06,
#   'epoch': 73.0,
#   'step': 1825},
#  {'loss': 2.7933,
#   'learning_rate': 5.344618055555556e-06,
#   'epoch': 74.0,
#   'step': 1850},
#  {'loss': 2.7337,
#   'learning_rate': 5.322916666666667e-06,
#   'epoch': 75.0,
#   'step': 1875},
#  {'loss': 2.7058,
#   'learning_rate': 5.301215277777778e-06,
#   'epoch': 76.0,
#   'step': 1900},
#  {'loss': 2.572,
#   'learning_rate': 5.2795138888888895e-06,
#   'epoch': 77.0,
#   'step': 1925},
#  {'loss': 2.5314,
#   'learning_rate': 5.257812500000001e-06,
#   'epoch': 78.0,
#   'step': 1950},
#  {'loss': 2.4963,
#   'learning_rate': 5.236111111111111e-06,
#   'epoch': 79.0,
#   'step': 1975},
#  {'loss': 2.4753,
#   'learning_rate': 5.214409722222222e-06,
#   'epoch': 80.0,
#   'step': 2000},
#  {'eval_loss': 2.342411518096924,
#   'eval_wer': 22.714942528735634,
#   'eval_runtime': 20.319,
#   'eval_samples_per_second': 2.461,
#   'eval_steps_per_second': 0.345,
#   'epoch': 80.0,
#   'step': 2000},
#  {'loss': 2.4243,
#   'learning_rate': 5.192708333333334e-06,
#   'epoch': 81.0,
#   'step': 2025},
#  {'loss': 2.2967,
#   'learning_rate': 5.171006944444445e-06,
#   'epoch': 82.0,
#   'step': 2050},
#  {'loss': 2.2187,
#   'learning_rate': 5.149305555555556e-06,
#   'epoch': 83.0,
#   'step': 2075},
#  {'loss': 2.1299,
#   'learning_rate': 5.127604166666667e-06,
#   'epoch': 84.0,
#   'step': 2100},
#  {'loss': 2.019,
#   'learning_rate': 5.105902777777779e-06,
#   'epoch': 85.0,
#   'step': 2125},
#  {'loss': 1.9332,
#   'learning_rate': 5.084201388888889e-06,
#   'epoch': 86.0,
#   'step': 2150},
#  {'loss': 1.9485, 'learning_rate': 5.0625e-06, 'epoch': 87.0, 'step': 2175},
#  {'loss': 1.8697,
#   'learning_rate': 5.0407986111111115e-06,
#   'epoch': 88.0,
#   'step': 2200},
#  {'loss': 1.7487,
#   'learning_rate': 5.019097222222222e-06,
#   'epoch': 89.0,
#   'step': 2225},
#  {'loss': 1.6941,
#   'learning_rate': 4.997395833333333e-06,
#   'epoch': 90.0,
#   'step': 2250},
#  {'loss': 1.6671,
#   'learning_rate': 4.975694444444444e-06,
#   'epoch': 91.0,
#   'step': 2275},
#  {'loss': 1.6314,
#   'learning_rate': 4.953993055555556e-06,
#   'epoch': 92.0,
#   'step': 2300},
#  {'loss': 1.5122,
#   'learning_rate': 4.932291666666667e-06,
#   'epoch': 93.0,
#   'step': 2325},
#  {'loss': 1.4282,
#   'learning_rate': 4.910590277777778e-06,
#   'epoch': 94.0,
#   'step': 2350},
#  {'loss': 1.3751,
#   'learning_rate': 4.888888888888889e-06,
#   'epoch': 95.0,
#   'step': 2375},
#  {'loss': 1.3192,
#   'learning_rate': 4.8671875000000006e-06,
#   'epoch': 96.0,
#   'step': 2400},
#  {'loss': 1.2606,
#   'learning_rate': 4.845486111111111e-06,
#   'epoch': 97.0,
#   'step': 2425},
#  {'loss': 1.1591,
#   'learning_rate': 4.823784722222222e-06,
#   'epoch': 98.0,
#   'step': 2450},
#  {'loss': 1.1003,
#   'learning_rate': 4.8020833333333334e-06,
#   'epoch': 99.0,
#   'step': 2475},
#  {'loss': 1.0179,
#   'learning_rate': 4.780381944444445e-06,
#   'epoch': 100.0,
#   'step': 2500},
#  {'loss': 0.9478,
#   'learning_rate': 4.758680555555556e-06,
#   'epoch': 101.0,
#   'step': 2525},
#  {'loss': 0.8698,
#   'learning_rate': 4.736979166666667e-06,
#   'epoch': 102.0,
#   'step': 2550},
#  {'loss': 0.8555,
#   'learning_rate': 4.715277777777778e-06,
#   'epoch': 103.0,
#   'step': 2575},
#  {'loss': 0.7935,
#   'learning_rate': 4.69357638888889e-06,
#   'epoch': 104.0,
#   'step': 2600},
#  {'loss': 0.744,
#   'learning_rate': 4.671875000000001e-06,
#   'epoch': 105.0,
#   'step': 2625},
#  {'loss': 0.6818,
#   'learning_rate': 4.650173611111111e-06,
#   'epoch': 106.0,
#   'step': 2650},
#  {'loss': 0.6353,
#   'learning_rate': 4.6284722222222225e-06,
#   'epoch': 107.0,
#   'step': 2675},
#  {'loss': 0.64,
#   'learning_rate': 4.606770833333334e-06,
#   'epoch': 108.0,
#   'step': 2700},
#  {'loss': 0.5563,
#   'learning_rate': 4.585069444444445e-06,
#   'epoch': 109.0,
#   'step': 2725},
#  {'loss': 0.5354,
#   'learning_rate': 4.563368055555555e-06,
#   'epoch': 110.0,
#   'step': 2750},
#  {'loss': 0.5005,
#   'learning_rate': 4.541666666666667e-06,
#   'epoch': 111.0,
#   'step': 2775},
#  {'loss': 0.4973,
#   'learning_rate': 4.519965277777778e-06,
#   'epoch': 112.0,
#   'step': 2800},
#  {'loss': 0.4736,
#   'learning_rate': 4.498263888888889e-06,
#   'epoch': 113.0,
#   'step': 2825},
#  {'loss': 0.4385,
#   'learning_rate': 4.4765625e-06,
#   'epoch': 114.0,
#   'step': 2850},
#  {'loss': 0.4059,
#   'learning_rate': 4.454861111111111e-06,
#   'epoch': 115.0,
#   'step': 2875},
#  {'loss': 0.4031,
#   'learning_rate': 4.433159722222222e-06,
#   'epoch': 116.0,
#   'step': 2900},
#  {'loss': 0.3813,
#   'learning_rate': 4.411458333333333e-06,
#   'epoch': 117.0,
#   'step': 2925},
#  {'loss': 0.3689,
#   'learning_rate': 4.3897569444444445e-06,
#   'epoch': 118.0,
#   'step': 2950},
#  {'loss': 0.3649,
#   'learning_rate': 4.368055555555556e-06,
#   'epoch': 119.0,
#   'step': 2975},
#  {'loss': 0.339,
#   'learning_rate': 4.346354166666667e-06,
#   'epoch': 120.0,
#   'step': 3000},
#  {'eval_loss': 0.32464599609375,
#   'eval_wer': 24.949425287356323,
#   'eval_runtime': 20.5253,
#   'eval_samples_per_second': 2.436,
#   'eval_steps_per_second': 0.341,
#   'epoch': 120.0,
#   'step': 3000},
#  {'loss': 0.3358,
#   'learning_rate': 4.324652777777778e-06,
#   'epoch': 121.0,
#   'step': 3025},
#  {'loss': 0.3136,
#   'learning_rate': 4.3029513888888895e-06,
#   'epoch': 122.0,
#   'step': 3050},
#  {'loss': 0.3106,
#   'learning_rate': 4.281250000000001e-06,
#   'epoch': 123.0,
#   'step': 3075},
#  {'loss': 0.3008,
#   'learning_rate': 4.259548611111111e-06,
#   'epoch': 124.0,
#   'step': 3100},
#  {'loss': 0.2935,
#   'learning_rate': 4.237847222222222e-06,
#   'epoch': 125.0,
#   'step': 3125},
#  {'loss': 0.2823,
#   'learning_rate': 4.216145833333334e-06,
#   'epoch': 126.0,
#   'step': 3150},
#  {'loss': 0.3007,
#   'learning_rate': 4.194444444444445e-06,
#   'epoch': 127.0,
#   'step': 3175},
#  {'loss': 0.2762,
#   'learning_rate': 4.172743055555556e-06,
#   'epoch': 128.0,
#   'step': 3200},
#  {'loss': 0.2635,
#   'learning_rate': 4.151041666666667e-06,
#   'epoch': 129.0,
#   'step': 3225},
#  {'loss': 0.2643,
#   'learning_rate': 4.1293402777777786e-06,
#   'epoch': 130.0,
#   'step': 3250},
#  {'loss': 0.2634,
#   'learning_rate': 4.107638888888889e-06,
#   'epoch': 131.0,
#   'step': 3275},
#  {'loss': 0.2604,
#   'learning_rate': 4.0859375e-06,
#   'epoch': 132.0,
#   'step': 3300},
#  {'loss': 0.2464,
#   'learning_rate': 4.064236111111111e-06,
#   'epoch': 133.0,
#   'step': 3325},
#  {'loss': 0.2544,
#   'learning_rate': 4.042534722222222e-06,
#   'epoch': 134.0,
#   'step': 3350},
#  {'loss': 0.2408,
#   'learning_rate': 4.020833333333333e-06,
#   'epoch': 135.0,
#   'step': 3375},
#  {'loss': 0.2312,
#   'learning_rate': 3.999131944444444e-06,
#   'epoch': 136.0,
#   'step': 3400},
#  {'loss': 0.229,
#   'learning_rate': 3.977430555555556e-06,
#   'epoch': 137.0,
#   'step': 3425},
#  {'loss': 0.2247,
#   'learning_rate': 3.955729166666667e-06,
#   'epoch': 138.0,
#   'step': 3450},
#  {'loss': 0.2348,
#   'learning_rate': 3.934027777777778e-06,
#   'epoch': 139.0,
#   'step': 3475},
#  {'loss': 0.2497,
#   'learning_rate': 3.912326388888889e-06,
#   'epoch': 140.0,
#   'step': 3500},
#  {'loss': 0.2182,
#   'learning_rate': 3.8906250000000005e-06,
#   'epoch': 141.0,
#   'step': 3525},
#  {'loss': 0.2223,
#   'learning_rate': 3.868923611111111e-06,
#   'epoch': 142.0,
#   'step': 3550},
#  {'loss': 0.216,
#   'learning_rate': 3.847222222222222e-06,
#   'epoch': 143.0,
#   'step': 3575},
#  {'loss': 0.2151,
#   'learning_rate': 3.8255208333333334e-06,
#   'epoch': 144.0,
#   'step': 3600},
#  {'loss': 0.2061,
#   'learning_rate': 3.8038194444444447e-06,
#   'epoch': 145.0,
#   'step': 3625},
#  {'loss': 0.2088,
#   'learning_rate': 3.782118055555556e-06,
#   'epoch': 146.0,
#   'step': 3650},
#  {'loss': 0.219,
#   'learning_rate': 3.760416666666667e-06,
#   'epoch': 147.0,
#   'step': 3675},
#  {'loss': 0.1951,
#   'learning_rate': 3.738715277777778e-06,
#   'epoch': 148.0,
#   'step': 3700},
#  {'loss': 0.2041,
#   'learning_rate': 3.7170138888888892e-06,
#   'epoch': 149.0,
#   'step': 3725},
#  {'loss': 0.1966,
#   'learning_rate': 3.6953125000000005e-06,
#   'epoch': 150.0,
#   'step': 3750},
#  {'loss': 0.2129,
#   'learning_rate': 3.673611111111111e-06,
#   'epoch': 151.0,
#   'step': 3775},
#  {'loss': 0.1927,
#   'learning_rate': 3.651909722222222e-06,
#   'epoch': 152.0,
#   'step': 3800},
#  {'loss': 0.2019,
#   'learning_rate': 3.6302083333333333e-06,
#   'epoch': 153.0,
#   'step': 3825},
#  {'loss': 0.1907,
#   'learning_rate': 3.6085069444444446e-06,
#   'epoch': 154.0,
#   'step': 3850},
#  {'loss': 0.1869,
#   'learning_rate': 3.586805555555556e-06,
#   'epoch': 155.0,
#   'step': 3875},
#  {'loss': 0.186,
#   'learning_rate': 3.565104166666667e-06,
#   'epoch': 156.0,
#   'step': 3900},
#  {'loss': 0.184,
#   'learning_rate': 3.5434027777777783e-06,
#   'epoch': 157.0,
#   'step': 3925},
#  {'loss': 0.1887,
#   'learning_rate': 3.521701388888889e-06,
#   'epoch': 158.0,
#   'step': 3950},
#  {'loss': 0.1878,
#   'learning_rate': 3.5000000000000004e-06,
#   'epoch': 159.0,
#   'step': 3975},
#  {'loss': 0.1802,
#   'learning_rate': 3.478298611111111e-06,
#   'epoch': 160.0,
#   'step': 4000},
#  {'eval_loss': 0.1931810826063156,
#   'eval_wer': 20.8183908045977,
#   'eval_runtime': 20.1918,
#   'eval_samples_per_second': 2.476,
#   'eval_steps_per_second': 0.347,
#   'epoch': 160.0,
#   'step': 4000},
#  {'loss': 0.1801,
#   'learning_rate': 3.456597222222222e-06,
#   'epoch': 161.0,
#   'step': 4025},
#  {'loss': 0.1825,
#   'learning_rate': 3.4348958333333333e-06,
#   'epoch': 162.0,
#   'step': 4050},
#  {'loss': 0.1709,
#   'learning_rate': 3.4131944444444445e-06,
#   'epoch': 163.0,
#   'step': 4075},
#  {'loss': 0.1655,
#   'learning_rate': 3.3914930555555557e-06,
#   'epoch': 164.0,
#   'step': 4100},
#  {'loss': 0.1711,
#   'learning_rate': 3.369791666666667e-06,
#   'epoch': 165.0,
#   'step': 4125},
#  {'loss': 0.1679,
#   'learning_rate': 3.3480902777777782e-06,
#   'epoch': 166.0,
#   'step': 4150},
#  {'loss': 0.1729,
#   'learning_rate': 3.3263888888888895e-06,
#   'epoch': 167.0,
#   'step': 4175},
#  {'loss': 0.1701,
#   'learning_rate': 3.3046875000000003e-06,
#   'epoch': 168.0,
#   'step': 4200},
#  {'loss': 0.1579,
#   'learning_rate': 3.282986111111111e-06,
#   'epoch': 169.0,
#   'step': 4225},
#  {'loss': 0.1674,
#   'learning_rate': 3.2612847222222223e-06,
#   'epoch': 170.0,
#   'step': 4250},
#  {'loss': 0.16,
#   'learning_rate': 3.239583333333333e-06,
#   'epoch': 171.0,
#   'step': 4275},
#  {'loss': 0.1525,
#   'learning_rate': 3.2178819444444444e-06,
#   'epoch': 172.0,
#   'step': 4300},
#  {'loss': 0.1556,
#   'learning_rate': 3.1961805555555556e-06,
#   'epoch': 173.0,
#   'step': 4325},
#  {'loss': 0.1555,
#   'learning_rate': 3.174479166666667e-06,
#   'epoch': 174.0,
#   'step': 4350},
#  {'loss': 0.1493,
#   'learning_rate': 3.152777777777778e-06,
#   'epoch': 175.0,
#   'step': 4375},
#  {'loss': 0.1473,
#   'learning_rate': 3.1310763888888894e-06,
#   'epoch': 176.0,
#   'step': 4400},
#  {'loss': 0.1418, 'learning_rate': 3.109375e-06, 'epoch': 177.0, 'step': 4425},
#  {'loss': 0.1456,
#   'learning_rate': 3.0876736111111114e-06,
#   'epoch': 178.0,
#   'step': 4450},
#  {'loss': 0.1424,
#   'learning_rate': 3.0659722222222227e-06,
#   'epoch': 179.0,
#   'step': 4475},
#  {'loss': 0.1402,
#   'learning_rate': 3.0442708333333335e-06,
#   'epoch': 180.0,
#   'step': 4500},
#  {'loss': 0.1489,
#   'learning_rate': 3.0225694444444447e-06,
#   'epoch': 181.0,
#   'step': 4525},
#  {'loss': 0.1357,
#   'learning_rate': 3.0008680555555556e-06,
#   'epoch': 182.0,
#   'step': 4550},
#  {'loss': 0.1374,
#   'learning_rate': 2.979166666666667e-06,
#   'epoch': 183.0,
#   'step': 4575},
#  {'loss': 0.1307,
#   'learning_rate': 2.9574652777777776e-06,
#   'epoch': 184.0,
#   'step': 4600},
#  {'loss': 0.1316,
#   'learning_rate': 2.935763888888889e-06,
#   'epoch': 185.0,
#   'step': 4625},
#  {'loss': 0.1271,
#   'learning_rate': 2.9140625e-06,
#   'epoch': 186.0,
#   'step': 4650},
#  {'loss': 0.1265,
#   'learning_rate': 2.8923611111111113e-06,
#   'epoch': 187.0,
#   'step': 4675},
#  {'loss': 0.1232,
#   'learning_rate': 2.8706597222222226e-06,
#   'epoch': 188.0,
#   'step': 4700},
#  {'loss': 0.1219,
#   'learning_rate': 2.8489583333333334e-06,
#   'epoch': 189.0,
#   'step': 4725},
#  {'loss': 0.1199,
#   'learning_rate': 2.8272569444444447e-06,
#   'epoch': 190.0,
#   'step': 4750},
#  {'loss': 0.1185,
#   'learning_rate': 2.805555555555556e-06,
#   'epoch': 191.0,
#   'step': 4775},
#  {'loss': 0.1227,
#   'learning_rate': 2.7838541666666667e-06,
#   'epoch': 192.0,
#   'step': 4800},
#  {'loss': 0.1151,
#   'learning_rate': 2.7621527777777775e-06,
#   'epoch': 193.0,
#   'step': 4825},
#  {'loss': 0.1129,
#   'learning_rate': 2.7404513888888888e-06,
#   'epoch': 194.0,
#   'step': 4850},
#  {'loss': 0.1125, 'learning_rate': 2.71875e-06, 'epoch': 195.0, 'step': 4875},
#  {'loss': 0.1109,
#   'learning_rate': 2.6970486111111113e-06,
#   'epoch': 196.0,
#   'step': 4900},
#  {'loss': 0.1138,
#   'learning_rate': 2.6753472222222225e-06,
#   'epoch': 197.0,
#   'step': 4925},
#  {'loss': 0.1037,
#   'learning_rate': 2.6536458333333333e-06,
#   'epoch': 198.0,
#   'step': 4950},
#  {'loss': 0.1017,
#   'learning_rate': 2.6319444444444446e-06,
#   'epoch': 199.0,
#   'step': 4975},
#  {'loss': 0.1041,
#   'learning_rate': 2.610243055555556e-06,
#   'epoch': 200.0,
#   'step': 5000},
#  {'eval_loss': 0.0973658636212349,
#   'eval_wer': 20.14712643678161,
#   'eval_runtime': 19.5237,
#   'eval_samples_per_second': 2.561,
#   'eval_steps_per_second': 0.359,
#   'epoch': 200.0,
#   'step': 5000},
#  {'loss': 0.1033,
#   'learning_rate': 2.588541666666667e-06,
#   'epoch': 201.0,
#   'step': 5025},
#  {'loss': 0.0999,
#   'learning_rate': 2.566840277777778e-06,
#   'epoch': 202.0,
#   'step': 5050},
#  {'loss': 0.0999,
#   'learning_rate': 2.545138888888889e-06,
#   'epoch': 203.0,
#   'step': 5075},
#  {'loss': 0.0991,
#   'learning_rate': 2.5234375e-06,
#   'epoch': 204.0,
#   'step': 5100},
#  {'loss': 0.098,
#   'learning_rate': 2.501736111111111e-06,
#   'epoch': 205.0,
#   'step': 5125},
#  {'loss': 0.0921,
#   'learning_rate': 2.4800347222222224e-06,
#   'epoch': 206.0,
#   'step': 5150},
#  {'loss': 0.0891,
#   'learning_rate': 2.4583333333333332e-06,
#   'epoch': 207.0,
#   'step': 5175},
#  {'loss': 0.0879,
#   'learning_rate': 2.4366319444444445e-06,
#   'epoch': 208.0,
#   'step': 5200},
#  {'loss': 0.1006,
#   'learning_rate': 2.4149305555555557e-06,
#   'epoch': 209.0,
#   'step': 5225},
#  {'loss': 0.0871,
#   'learning_rate': 2.393229166666667e-06,
#   'epoch': 210.0,
#   'step': 5250},
#  {'loss': 0.0867,
#   'learning_rate': 2.3715277777777778e-06,
#   'epoch': 211.0,
#   'step': 5275},
#  {'loss': 0.0907,
#   'learning_rate': 2.349826388888889e-06,
#   'epoch': 212.0,
#   'step': 5300},
#  {'loss': 0.0833,
#   'learning_rate': 2.3281250000000003e-06,
#   'epoch': 213.0,
#   'step': 5325},
#  {'loss': 0.0886,
#   'learning_rate': 2.306423611111111e-06,
#   'epoch': 214.0,
#   'step': 5350},
#  {'loss': 0.0834,
#   'learning_rate': 2.2847222222222223e-06,
#   'epoch': 215.0,
#   'step': 5375},
#  {'loss': 0.0823,
#   'learning_rate': 2.263020833333333e-06,
#   'epoch': 216.0,
#   'step': 5400},
#  {'loss': 0.0832,
#   'learning_rate': 2.2413194444444444e-06,
#   'epoch': 217.0,
#   'step': 5425},
#  {'loss': 0.0722,
#   'learning_rate': 2.2196180555555556e-06,
#   'epoch': 218.0,
#   'step': 5450},
#  {'loss': 0.0853,
#   'learning_rate': 2.197916666666667e-06,
#   'epoch': 219.0,
#   'step': 5475},
#  {'loss': 0.077,
#   'learning_rate': 2.1762152777777777e-06,
#   'epoch': 220.0,
#   'step': 5500},
#  {'loss': 0.0725,
#   'learning_rate': 2.154513888888889e-06,
#   'epoch': 221.0,
#   'step': 5525},
#  {'loss': 0.0683,
#   'learning_rate': 2.1328125e-06,
#   'epoch': 222.0,
#   'step': 5550},
#  {'loss': 0.0775,
#   'learning_rate': 2.1111111111111114e-06,
#   'epoch': 223.0,
#   'step': 5575},
#  {'loss': 0.0695,
#   'learning_rate': 2.0894097222222227e-06,
#   'epoch': 224.0,
#   'step': 5600},
#  {'loss': 0.0805,
#   'learning_rate': 2.0677083333333335e-06,
#   'epoch': 225.0,
#   'step': 5625},
#  {'loss': 0.0874,
#   'learning_rate': 2.0460069444444443e-06,
#   'epoch': 226.0,
#   'step': 5650},
#  {'loss': 0.0657,
#   'learning_rate': 2.0243055555555555e-06,
#   'epoch': 227.0,
#   'step': 5675},
#  {'loss': 0.064,
#   'learning_rate': 2.0026041666666668e-06,
#   'epoch': 228.0,
#   'step': 5700},
#  {'loss': 0.0604,
#   'learning_rate': 1.9809027777777776e-06,
#   'epoch': 229.0,
#   'step': 5725},
#  {'loss': 0.0652,
#   'learning_rate': 1.959201388888889e-06,
#   'epoch': 230.0,
#   'step': 5750},
#  {'loss': 0.0573, 'learning_rate': 1.9375e-06, 'epoch': 231.0, 'step': 5775},
#  {'loss': 0.061,
#   'learning_rate': 1.9157986111111113e-06,
#   'epoch': 232.0,
#   'step': 5800},
#  {'loss': 0.0657,
#   'learning_rate': 1.8940972222222224e-06,
#   'epoch': 233.0,
#   'step': 5825},
#  {'loss': 0.0579,
#   'learning_rate': 1.8723958333333334e-06,
#   'epoch': 234.0,
#   'step': 5850},
#  {'loss': 0.0655,
#   'learning_rate': 1.8506944444444444e-06,
#   'epoch': 235.0,
#   'step': 5875},
#  {'loss': 0.062,
#   'learning_rate': 1.8289930555555557e-06,
#   'epoch': 236.0,
#   'step': 5900},
#  {'loss': 0.0504,
#   'learning_rate': 1.807291666666667e-06,
#   'epoch': 237.0,
#   'step': 5925},
#  {'loss': 0.0536,
#   'learning_rate': 1.7855902777777777e-06,
#   'epoch': 238.0,
#   'step': 5950},
#  {'loss': 0.0525,
#   'learning_rate': 1.763888888888889e-06,
#   'epoch': 239.0,
#   'step': 5975},
#  {'loss': 0.0543,
#   'learning_rate': 1.7421875e-06,
#   'epoch': 240.0,
#   'step': 6000},
#  {'eval_loss': 0.04190904274582863,
#   'eval_wer': 18.466666666666665,
#   'eval_runtime': 21.1348,
#   'eval_samples_per_second': 2.366,
#   'eval_steps_per_second': 0.331,
#   'epoch': 240.0,
#   'step': 6000},
#  {'loss': 0.0603,
#   'learning_rate': 1.7204861111111112e-06,
#   'epoch': 241.0,
#   'step': 6025},
#  {'loss': 0.0585,
#   'learning_rate': 1.6987847222222225e-06,
#   'epoch': 242.0,
#   'step': 6050},
#  {'loss': 0.0452,
#   'learning_rate': 1.6770833333333333e-06,
#   'epoch': 243.0,
#   'step': 6075},
#  {'loss': 0.0545,
#   'learning_rate': 1.6553819444444445e-06,
#   'epoch': 244.0,
#   'step': 6100},
#  {'loss': 0.0474,
#   'learning_rate': 1.6336805555555556e-06,
#   'epoch': 245.0,
#   'step': 6125},
#  {'loss': 0.0513,
#   'learning_rate': 1.6119791666666668e-06,
#   'epoch': 246.0,
#   'step': 6150},
#  {'loss': 0.0438,
#   'learning_rate': 1.5902777777777776e-06,
#   'epoch': 247.0,
#   'step': 6175},
#  {'loss': 0.0419,
#   'learning_rate': 1.5685763888888889e-06,
#   'epoch': 248.0,
#   'step': 6200},
#  {'loss': 0.0395,
#   'learning_rate': 1.5468750000000001e-06,
#   'epoch': 249.0,
#   'step': 6225},
#  {'loss': 0.0504,
#   'learning_rate': 1.5251736111111111e-06,
#   'epoch': 250.0,
#   'step': 6250},
#  {'loss': 0.041,
#   'learning_rate': 1.5034722222222222e-06,
#   'epoch': 251.0,
#   'step': 6275},
#  {'loss': 0.0405,
#   'learning_rate': 1.4817708333333334e-06,
#   'epoch': 252.0,
#   'step': 6300},
#  {'loss': 0.041,
#   'learning_rate': 1.4600694444444445e-06,
#   'epoch': 253.0,
#   'step': 6325},
#  {'loss': 0.04,
#   'learning_rate': 1.4383680555555557e-06,
#   'epoch': 254.0,
#   'step': 6350},
#  {'loss': 0.0365,
#   'learning_rate': 1.4166666666666667e-06,
#   'epoch': 255.0,
#   'step': 6375},
#  {'loss': 0.0379,
#   'learning_rate': 1.3949652777777778e-06,
#   'epoch': 256.0,
#   'step': 6400},
#  {'loss': 0.0362,
#   'learning_rate': 1.373263888888889e-06,
#   'epoch': 257.0,
#   'step': 6425},
#  {'loss': 0.0351,
#   'learning_rate': 1.3515625e-06,
#   'epoch': 258.0,
#   'step': 6450},
#  {'loss': 0.0338,
#   'learning_rate': 1.3298611111111113e-06,
#   'epoch': 259.0,
#   'step': 6475},
#  {'loss': 0.0366,
#   'learning_rate': 1.3081597222222223e-06,
#   'epoch': 260.0,
#   'step': 6500},
#  {'loss': 0.0428,
#   'learning_rate': 1.2864583333333333e-06,
#   'epoch': 261.0,
#   'step': 6525},
#  {'loss': 0.0444,
#   'learning_rate': 1.2647569444444444e-06,
#   'epoch': 262.0,
#   'step': 6550},
#  {'loss': 0.0366,
#   'learning_rate': 1.2430555555555556e-06,
#   'epoch': 263.0,
#   'step': 6575},
#  {'loss': 0.0298,
#   'learning_rate': 1.2213541666666666e-06,
#   'epoch': 264.0,
#   'step': 6600},
#  {'loss': 0.0404,
#   'learning_rate': 1.1996527777777779e-06,
#   'epoch': 265.0,
#   'step': 6625},
#  {'loss': 0.0287,
#   'learning_rate': 1.1779513888888891e-06,
#   'epoch': 266.0,
#   'step': 6650},
#  {'loss': 0.0368, 'learning_rate': 1.15625e-06, 'epoch': 267.0, 'step': 6675},
#  {'loss': 0.0292,
#   'learning_rate': 1.1345486111111112e-06,
#   'epoch': 268.0,
#   'step': 6700},
#  {'loss': 0.0349,
#   'learning_rate': 1.1128472222222222e-06,
#   'epoch': 269.0,
#   'step': 6725},
#  {'loss': 0.027,
#   'learning_rate': 1.0911458333333335e-06,
#   'epoch': 270.0,
#   'step': 6750},
#  {'loss': 0.0284,
#   'learning_rate': 1.0694444444444445e-06,
#   'epoch': 271.0,
#   'step': 6775},
#  {'loss': 0.0259,
#   'learning_rate': 1.0477430555555557e-06,
#   'epoch': 272.0,
#   'step': 6800},
#  {'loss': 0.0255,
#   'learning_rate': 1.0260416666666665e-06,
#   'epoch': 273.0,
#   'step': 6825},
#  {'loss': 0.0252,
#   'learning_rate': 1.0043402777777778e-06,
#   'epoch': 274.0,
#   'step': 6850},
#  {'loss': 0.0263,
#   'learning_rate': 9.82638888888889e-07,
#   'epoch': 275.0,
#   'step': 6875},
#  {'loss': 0.0241, 'learning_rate': 9.609375e-07, 'epoch': 276.0, 'step': 6900},
#  {'loss': 0.0243,
#   'learning_rate': 9.392361111111112e-07,
#   'epoch': 277.0,
#   'step': 6925},
#  {'loss': 0.03,
#   'learning_rate': 9.175347222222222e-07,
#   'epoch': 278.0,
#   'step': 6950},
#  {'loss': 0.0295,
#   'learning_rate': 8.958333333333334e-07,
#   'epoch': 279.0,
#   'step': 6975},
#  {'loss': 0.0215,
#   'learning_rate': 8.741319444444444e-07,
#   'epoch': 280.0,
#   'step': 7000},
#  {'eval_loss': 0.01825772225856781,
#   'eval_wer': 15.970114942528735,
#   'eval_runtime': 20.9597,
#   'eval_samples_per_second': 2.386,
#   'eval_steps_per_second': 0.334,
#   'epoch': 280.0,
#   'step': 7000},
#  {'loss': 0.0262,
#   'learning_rate': 8.524305555555556e-07,
#   'epoch': 281.0,
#   'step': 7025},
#  {'loss': 0.0222,
#   'learning_rate': 8.307291666666667e-07,
#   'epoch': 282.0,
#   'step': 7050},
#  {'loss': 0.0241,
#   'learning_rate': 8.090277777777778e-07,
#   'epoch': 283.0,
#   'step': 7075},
#  {'loss': 0.0201,
#   'learning_rate': 7.87326388888889e-07,
#   'epoch': 284.0,
#   'step': 7100},
#  {'loss': 0.0205, 'learning_rate': 7.65625e-07, 'epoch': 285.0, 'step': 7125},
#  {'loss': 0.0224,
#   'learning_rate': 7.439236111111111e-07,
#   'epoch': 286.0,
#   'step': 7150},
#  {'loss': 0.0205,
#   'learning_rate': 7.222222222222222e-07,
#   'epoch': 287.0,
#   'step': 7175},
#  {'loss': 0.0194,
#   'learning_rate': 7.005208333333333e-07,
#   'epoch': 288.0,
#   'step': 7200},
#  {'loss': 0.0212,
#   'learning_rate': 6.788194444444445e-07,
#   'epoch': 289.0,
#   'step': 7225},
#  {'loss': 0.0196,
#   'learning_rate': 6.571180555555557e-07,
#   'epoch': 290.0,
#   'step': 7250},
#  {'loss': 0.0199,
#   'learning_rate': 6.354166666666667e-07,
#   'epoch': 291.0,
#   'step': 7275},
#  {'loss': 0.0204,
#   'learning_rate': 6.137152777777778e-07,
#   'epoch': 292.0,
#   'step': 7300},
#  {'loss': 0.0197,
#   'learning_rate': 5.92013888888889e-07,
#   'epoch': 293.0,
#   'step': 7325},
#  {'loss': 0.0176, 'learning_rate': 5.703125e-07, 'epoch': 294.0, 'step': 7350},
#  {'loss': 0.0207,
#   'learning_rate': 5.486111111111111e-07,
#   'epoch': 295.0,
#   'step': 7375},
#  {'loss': 0.0169,
#   'learning_rate': 5.269097222222223e-07,
#   'epoch': 296.0,
#   'step': 7400},
#  {'loss': 0.0184,
#   'learning_rate': 5.052083333333333e-07,
#   'epoch': 297.0,
#   'step': 7425},
#  {'loss': 0.017,
#   'learning_rate': 4.835069444444445e-07,
#   'epoch': 298.0,
#   'step': 7450},
#  {'loss': 0.0165,
#   'learning_rate': 4.618055555555556e-07,
#   'epoch': 299.0,
#   'step': 7475},
#  {'loss': 0.0161,
#   'learning_rate': 4.401041666666667e-07,
#   'epoch': 300.0,
#   'step': 7500},
#  {'loss': 0.0159,
#   'learning_rate': 4.184027777777778e-07,
#   'epoch': 301.0,
#   'step': 7525},
#  {'loss': 0.0161,
#   'learning_rate': 3.967013888888889e-07,
#   'epoch': 302.0,
#   'step': 7550},
#  {'loss': 0.0157, 'learning_rate': 3.75e-07, 'epoch': 303.0, 'step': 7575},
#  {'loss': 0.0146,
#   'learning_rate': 3.5329861111111115e-07,
#   'epoch': 304.0,
#   'step': 7600},
#  {'loss': 0.0157,
#   'learning_rate': 3.3159722222222223e-07,
#   'epoch': 305.0,
#   'step': 7625},
#  {'loss': 0.0142,
#   'learning_rate': 3.0989583333333337e-07,
#   'epoch': 306.0,
#   'step': 7650},
#  {'loss': 0.0138,
#   'learning_rate': 2.8819444444444445e-07,
#   'epoch': 307.0,
#   'step': 7675},
#  {'loss': 0.0137,
#   'learning_rate': 2.6649305555555553e-07,
#   'epoch': 308.0,
#   'step': 7700},
#  {'loss': 0.0147,
#   'learning_rate': 2.4479166666666667e-07,
#   'epoch': 309.0,
#   'step': 7725},
#  {'loss': 0.0135,
#   'learning_rate': 2.230902777777778e-07,
#   'epoch': 310.0,
#   'step': 7750},
#  {'loss': 0.0132,
#   'learning_rate': 2.013888888888889e-07,
#   'epoch': 311.0,
#   'step': 7775},
#  {'loss': 0.0133,
#   'learning_rate': 1.7968750000000003e-07,
#   'epoch': 312.0,
#   'step': 7800},
#  {'loss': 0.0129,
#   'learning_rate': 1.579861111111111e-07,
#   'epoch': 313.0,
#   'step': 7825},
#  {'loss': 0.0127,
#   'learning_rate': 1.3628472222222225e-07,
#   'epoch': 314.0,
#   'step': 7850},
#  {'loss': 0.0126,
#   'learning_rate': 1.1458333333333334e-07,
#   'epoch': 315.0,
#   'step': 7875},
#  {'loss': 0.0123,
#   'learning_rate': 9.288194444444445e-08,
#   'epoch': 316.0,
#   'step': 7900},
#  {'loss': 0.0121,
#   'learning_rate': 7.118055555555556e-08,
#   'epoch': 317.0,
#   'step': 7925},
#  {'loss': 0.012,
#   'learning_rate': 4.9479166666666674e-08,
#   'epoch': 318.0,
#   'step': 7950},
#  {'loss': 0.0118,
#   'learning_rate': 2.777777777777778e-08,
#   'epoch': 319.0,
#   'step': 7975},
#  {'loss': 0.0117,
#   'learning_rate': 6.076388888888889e-09,
#   'epoch': 320.0,
#   'step': 8000},
#  {'eval_loss': 0.008823619224131107,
#   'eval_wer': 14.549425287356321,
#   'eval_runtime': 20.6724,
#   'eval_samples_per_second': 2.419,
#   'eval_steps_per_second': 0.339,
#   'epoch': 320.0,
#   'step': 8000},
#  {'train_runtime': 16560.319,
#   'train_samples_per_second': 7.729,
#   'train_steps_per_second': 0.483,
#   'total_flos': 3.693893124096e+19,
#   'train_loss': 2.560914797578007,
#   'epoch': 320.0,
#   'step': 8000},
#  {'eval_loss': 0.008823619224131107,
#   'eval_wer': 14.549425287356321,
#   'eval_runtime': 20.5723,
#   'eval_samples_per_second': 2.43,
#   'eval_steps_per_second': 0.34,
#   'epoch': 320.0,
#   'step': 8000}]

# %%
import pandas as pd
result = pd.DataFrame(trainer.state.log_history)

# %%
result.to_csv('Result_finetune_TimeStretch.csv')
